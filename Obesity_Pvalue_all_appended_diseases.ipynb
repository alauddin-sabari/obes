# %%
import pandas as pd 
import numpy as np

#Import libraries
from matplotlib_venn import venn2, venn2_circles
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
d1  = pd.read_csv('Bipolar_disorder/Data/appended_BD.csv')
d1  = d1[(abs(d1['Log_FoldChange'])>1) & (d1['PValue'] <0.05)]
#d1  = d1[(abs(d['Log_FoldChange'])>1) & (d1['FDR_adjusted_P.value'] <0.05)]

up = d1[d1['Log_FoldChange']>1]

up = up.drop_duplicates(subset='Gene_symbol')


set2up = set()

for i in up['Gene_symbol'].values:
 
    set2up.add(i)

# %%
d  = pd.read_csv('Obesity/Data/appended_these_datasets.csv')
d  = d[(abs(d['Log_FoldChange'])>1) & (d['PValue'] <0.05)]
up = d[d['Log_FoldChange']>1]

up = up.drop_duplicates(subset='Gene_symbol')


set1up = set()

for i in up['Gene_symbol'].values:
 
    set1up.add(i)
 

d1  = pd.read_csv('Bipolar_disorder/Data/appended_BD.csv')
d1  = d1[(abs(d1['Log_FoldChange'])>1) & (d1['PValue'] <0.05)]
#d1  = d1[(abs(d['Log_FoldChange'])>1) & (d1['FDR_adjusted_P.value'] <0.05)]

up = d1[d1['Log_FoldChange']>1]

up = up.drop_duplicates(subset='Gene_symbol')


set2up = set()

for i in up['Gene_symbol'].values:
 
    set2up.add(i)


fig= plt.figure()
ax= fig.add_subplot(111)
from venn import venn
# %matplotlib inline

musicians = {
    "Obesity_up": set1up,
    "Bipolar_up": set2up
    }
venn(musicians)
# Out:
# <AxesSubplot:>

# %%
fig= plt.figure()
ax= fig.add_subplot(111)
# %matplotlib inline   
musicians = {
    "Obesity_up": set1up,
    "Bipolar_up": set2up
    }
venn(musicians)
# Out:
# <AxesSubplot:>

# %% [markdown]
# Dataset's link:<br>https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE58933

# %%
d  = pd.read_csv('Obesity/Data/appended_these_datasets.csv')
d  = d[(abs(d['Log_FoldChange'])>1) & (d['PValue'] <0.05)]
up = d[d['Log_FoldChange']>1]

up = up.drop_duplicates(subset='Gene_symbol')


set1up = set()

for i in up['Gene_symbol'].values:
 
    set1up.add(i)
 
 
down = d[d['Log_FoldChange']<-1]
 
down = down.drop_duplicates(subset='Gene_symbol')
 
set1down = set()
 
for i in down['Gene_symbol'].values:

    set1down.add(i)

# %%
d1  = pd.read_csv('Bipolar_disorder/Data/appended_BD.csv')
d1  = d1[(abs(d1['Log_FoldChange'])>1) & (d1['PValue'] <0.05)]
#d1  = d1[(abs(d['Log_FoldChange'])>1) & (d1['FDR_adjusted_P.value'] <0.05)]

up = d1[d1['Log_FoldChange']>1]

up = up.drop_duplicates(subset='Gene_symbol')


set2up = set()

for i in up['Gene_symbol'].values:
 
    set2up.add(i)
 
 
down = d1[d1['Log_FoldChange']<-1]
 
down = down.drop_duplicates(subset='Gene_symbol')
 
set2down = set()
 
for i in down['Gene_symbol'].values:

    set2down.add(i)

# %%
from venn import venn
# %matplotlib inline

musicians = {
    "Obesity_up": set1up,
    "Bipolar_up": set2up
    }
venn(musicians)
# Out:
# <AxesSubplot:>

# %%
from venn import venn
# %matplotlib inline

musicians = {
    "Obesity_down": set1down,
    "Bipolar_down": set2down
    }
venn(musicians)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Major_depression

# %%
d1  = pd.read_csv('Major_depression/Data/append_MD.csv')
d1  = d1[(abs(d1['Log_FoldChange'])>1) & (d1['PValue'] <0.05)]
#d1  = d1[(abs(d['Log_FoldChange'])>1) & (d1['FDR_adjusted_P.value'] <0.05)]

up = d1[d1['Log_FoldChange']>1]

up = up.drop_duplicates(subset='Gene_symbol')


set2up = set()

for i in up['Gene_symbol'].values:
 
    set2up.add(i)
 
 
down = d1[d1['Log_FoldChange']<-1]
 
down = down.drop_duplicates(subset='Gene_symbol')
 
set2down = set()
 
for i in down['Gene_symbol'].values:

    set2down.add(i)

# %%
from venn import venn
# %matplotlib inline

musicians = {
    "Obesity_up": set1up,
    "Major_depression_up": set2up
    }
venn(musicians)
# Out:
# <AxesSubplot:>

# %%
from venn import venn
# %matplotlib inline

musicians = {
    "Obesity_down": set1down,
    "Major_depression": set2down
    }
venn(musicians)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # PTSD

# %%
d1  = pd.read_csv('PTSD/Data/append_PTSD.csv')
d1  = d1[(abs(d1['Log_FoldChange'])>1) & (d1['PValue'] <0.05)]
#d1  = d1[(abs(d['Log_FoldChange'])>1) & (d1['FDR_adjusted_P.value'] <0.05)]

up = d1[d1['Log_FoldChange']>1]

up = up.drop_duplicates(subset='Gene_symbol')


set2up = set()

for i in up['Gene_symbol'].values:
 
    set2up.add(i)
 
 
down = d1[d1['Log_FoldChange']<-1]
 
down = down.drop_duplicates(subset='Gene_symbol')
 
set2down = set()
 
for i in down['Gene_symbol'].values:

    set2down.add(i)

# %%
from venn import venn
# %matplotlib inline

musicians = {
    "Obesity_up": set1up,
    "PTSD_up": set2up
    }
venn(musicians)
# Out:
# <AxesSubplot:>

# %%
from venn import venn
# %matplotlib inline

musicians = {
    "Obesity_down": set1down,
    "PTSD_down": set2down
    }
venn(musicians)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Schizophrenia

# %%
d1  = pd.read_csv('Schizophrenia/Data/appended_SZ.csv')
d1  = d1[(abs(d1['Log_FoldChange'])>1) & (d1['PValue'] <0.05)]
#d1  = d1[(abs(d['Log_FoldChange'])>1) & (d1['FDR_adjusted_P.value'] <0.05)]

up = d1[d1['Log_FoldChange']>1]

up = up.drop_duplicates(subset='Gene_symbol')


set2up = set()

for i in up['Gene_symbol'].values:
 
    set2up.add(i)
 
 
down = d1[d1['Log_FoldChange']<-1]
 
down = down.drop_duplicates(subset='Gene_symbol')
 
set2down = set()
 
for i in down['Gene_symbol'].values:

    set2down.add(i)

# %%
from venn import venn
# %matplotlib inline

musicians = {
    "Obesity_up": set1up,
    "Schizophrenia_up": set2up
    }
venn(musicians)
# Out:
# <AxesSubplot:>

# %%
from venn import venn
# %matplotlib inline

musicians = {
    "Obesity_down": set1down,
    "Schizophrenia_down": set2down
    }
venn(musicians)
# Out:
# <AxesSubplot:>
