# %%
import pandas as pd 
import numpy as np

#Import libraries
from matplotlib_venn import venn2, venn2_circles
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Dataset's link:<br>https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE58933

# %%
d  = pd.read_csv('GSE81396/GSE81396_BD_Braintissue_Putamen_subtissue.csv')
#d

# %% [markdown]
# # Filtered Datataset

# %%
d  = d[(abs(d['Log_FoldChange'])>0.5) & (d['FDR_adjusted_P.value'] <0.1)]
d.dropna(subset = ['Gene_symbol'], inplace = True)
d[['Gene_symbol','Log_FoldChange','FDR_adjusted_P.value']]
# Out:
#    Gene_symbol  Log_FoldChange  FDR_adjusted_P.value
# 0        HLA-E           9.439          2.043155e-15
# 1        HLA-E           9.439          2.043155e-15
# 2        HLA-E           9.439          2.043155e-15
# 3         GNL1          -4.859          1.212896e-10
# 4         CHAT          -4.059          6.645638e-05
# 5         MDC1          -6.342          1.736711e-04
# 6         GNL1          -4.018          1.819466e-04
# 7        ECEL1          -3.148          2.815276e-04
# 8     HLA-DPA1           3.330          4.707362e-04
# 9         GNL1           2.637          4.707362e-04
# 10        GNL1           2.637          4.707362e-04
# 11        GNL1           2.637          4.707362e-04
# 12    HLA-DPA1           3.325          4.748873e-04
# 13       NTRK1          -3.554          6.876803e-04
# 14         MAL          -2.443          7.201118e-04
# 15      PDXDC1          -2.100          1.088569e-03
# 16       ANXA1           2.465          1.734071e-03
# 17        GNL1          -3.268          1.789573e-03
# 18       ABCF1           3.376          8.615073e-03
# 19       ABCF1           3.376          8.615073e-03
# 20         NSF          -7.332          8.615073e-03
# 21       CXCL8           4.582          9.224700e-03
# 22         SST          -2.434          9.344070e-03
# 23         MOG          -8.226          1.188793e-02
# 24        PRR3           3.177          1.678059e-02
# 25        PRR3           3.180          1.678059e-02
# 26        PRR3           3.180          1.678059e-02
# 27       TAPBP           5.200          1.705360e-02
# 28        PDK2          -1.626          3.375825e-02
# 29    MTRNR2L6          -6.711          5.014590e-02
# 30        CD99          -1.678          5.202515e-02
# 31        OTOF          -1.643          5.202515e-02
# 32       HLA-A          -7.369          5.323766e-02
# 33      FBXO31          -2.582          6.612755e-02
# 34       CDC20          -5.546          6.994154e-02
# 35         BSG          -1.811          6.994154e-02

# %% [markdown]
# # Up Regulated Genes

# %%
up = d[d['Log_FoldChange']>.5]
print(f"{up.shape}-->dataset's shape",f'||Amount of genes before removing duplication  {up.shape[0]}')
print('________________________________________________________________')
up = up.drop_duplicates(subset='Gene_symbol')
print(f"{up.shape}-->dataset's shape",f'||Amount of genes before removing duplication  {up.shape[0]}')

up[['Gene_symbol', 'Log_FoldChange','FDR_adjusted_P.value']]
# Out:
# (16, 8)-->dataset's shape ||Amount of genes before removing duplication  16
# ________________________________________________________________
# (8, 8)-->dataset's shape ||Amount of genes before removing duplication  8
#    Gene_symbol  Log_FoldChange  FDR_adjusted_P.value
# 0        HLA-E           9.439          2.043155e-15
# 8     HLA-DPA1           3.330          4.707362e-04
# 9         GNL1           2.637          4.707362e-04
# 16       ANXA1           2.465          1.734071e-03
# 18       ABCF1           3.376          8.615073e-03
# 21       CXCL8           4.582          9.224700e-03
# 24        PRR3           3.177          1.678059e-02
# 27       TAPBP           5.200          1.705360e-02

# %% [markdown]
# # Down Regulated Genes

# %%
down = d[d['Log_FoldChange']<-.5] #condition for finding downreagulated genes

print(f"dataset's shape{down.shape}",f'||Amount of genes before removing duplication  {down.shape[0]}')
print('________________________________________________________________')
down = down.drop_duplicates(subset='Gene_symbol') #removing duplicated genes
print(f"dataset's shape{down.shape}",f'||Amount of genes after removing duplication   {down.shape[0]}')

down[['Gene_symbol', 'Log_FoldChange','FDR_adjusted_P.value']]
# Out:
# dataset's shape(20, 8) ||Amount of genes before removing duplication  20
# ________________________________________________________________
# dataset's shape(18, 8) ||Amount of genes after removing duplication   18
#    Gene_symbol  Log_FoldChange  FDR_adjusted_P.value
# 3         GNL1          -4.859          1.212896e-10
# 4         CHAT          -4.059          6.645638e-05
# 5         MDC1          -6.342          1.736711e-04
# 7        ECEL1          -3.148          2.815276e-04
# 13       NTRK1          -3.554          6.876803e-04
# 14         MAL          -2.443          7.201118e-04
# 15      PDXDC1          -2.100          1.088569e-03
# 20         NSF          -7.332          8.615073e-03
# 22         SST          -2.434          9.344070e-03
# 23         MOG          -8.226          1.188793e-02
# 28        PDK2          -1.626          3.375825e-02
# 29    MTRNR2L6          -6.711          5.014590e-02
# 30        CD99          -1.678          5.202515e-02
# 31        OTOF          -1.643          5.202515e-02
# 32       HLA-A          -7.369          5.323766e-02
# 33      FBXO31          -2.582          6.612755e-02
# 34       CDC20          -5.546          6.994154e-02
# 35         BSG          -1.811          6.994154e-02

# %%
d  = pd.read_csv('GSE81396/GSE81396_BD_Braintissue_cuadate_nucleus_subtissue.csv')
#d

# %% [markdown]
# # Filtered Datataset

# %%
d  = d[(abs(d['Log_FoldChange'])>0.5) & (d['FDR_adjusted_P.value'] <0.1)]
d.dropna(subset = ['Gene_symbol'], inplace = True)
d[['Gene_symbol','Log_FoldChange','FDR_adjusted_P.value']]
# Out:
#       Gene_symbol  Log_FoldChange  FDR_adjusted_P.value
# 0           HLA-E           9.675          6.221723e-15
# 1           HLA-E           9.675          6.221723e-15
# 2           HLA-E           9.675          6.221723e-15
# 3            ADI1           7.374          8.753403e-08
# 4           PTGR1          -7.442          3.668371e-07
# 5             MOG          -8.569          5.160095e-06
# 6             MOG          -5.625          1.055036e-05
# 7            GNL1           3.803          1.294855e-05
# 8            GNL1           3.803          1.294855e-05
# 9            GNL1           3.803          1.294855e-05
# 10           GNL1          -5.388          1.294855e-05
# 11           PBX2          -4.052          1.284599e-04
# 12           PRR3           4.487          3.405242e-04
# 13           PRR3           4.487          3.405242e-04
# 14          HLA-C          -7.142          6.275805e-04
# 15          CXCL8           3.735          6.500416e-04
# 16           GNL1          -4.355          6.888139e-04
# 17          PCSK5           7.525          2.956713e-03
# 18            MOG          -4.216          7.813115e-03
# 19          TPPP3          -2.440          7.813115e-03
# 20   LOC100996721           6.039          8.448130e-03
# 21        NEUROD2           5.502          1.126761e-02
# 22          LMOD3           6.587          1.337313e-02
# 23          FGF23           5.450          1.519407e-02
# 24           PPT2          -5.273          2.270346e-02
# 25           DDR1          -5.241          2.270346e-02
# 26        SNORA21           5.360          2.709503e-02
# 27          RNU12           2.353          2.954453e-02
# 28      LOC554223           5.229          3.444740e-02
# 29            NSF          -6.934          3.444740e-02
# 30          GREM1           4.585          3.444740e-02
# 31          GREM1           4.585          3.444740e-02
# 32        CEBPZOS           4.611          3.808028e-02
# 33         CHI3L2          -3.102          4.142218e-02
# 34         CXCL14           3.924          4.142218e-02
# 35         LRRC69           4.403          4.255268e-02
# 36       RNU6ATAC           2.010          4.397319e-02
# 37           MUC4           4.416          4.824256e-02
# 38          NABP1           4.466          4.824256e-02
# 39          SMOC1          -2.307          5.157695e-02
# 40    SNORD116-22           5.673          5.226233e-02
# 41          HLA-F           4.455          5.540448e-02
# 42         WT1-AS           5.579          5.540448e-02
# 43      LOC283038           4.227          5.540448e-02
# 44         COL6A3           4.080          5.540448e-02
# 45          PRRG3           3.882          5.540448e-02
# 46       MTRNR2L2           2.159          5.581676e-02
# 47          NCALD           4.094          6.723877e-02
# 48            DES          -6.082          6.903464e-02
# 49        FAM184B           3.999          7.001840e-02
# 50   LOC101929657          -3.303          7.240748e-02
# 51        SCARNA4           3.636          7.240748e-02
# 52          CXCL1           2.524          7.240748e-02
# 53      LINC00261           3.645          7.240748e-02
# 54        SLC45A3          -2.605          7.240748e-02
# 55           TPH1           4.447          7.240748e-02
# 56        SNORA81           1.813          7.240748e-02
# 57           KLK6          -2.597          7.240748e-02
# 58      LOC554223           3.126          7.240748e-02
# 59          MUC3A           5.048          7.281140e-02
# 60           DBET           5.332          7.281140e-02
# 61          S1PR2           4.281          7.281140e-02
# 62          HLA-B          -3.151          7.420031e-02
# 63   LOC100506675           3.202          7.524935e-02
# 64          AP2A2          -1.742          7.597184e-02
# 65           PLTP          -1.762          7.597184e-02
# 66          CHADL          -2.281          7.978958e-02
# 67         ELOVL1          -2.415          7.981912e-02
# 68          AEBP1          -1.855          7.981912e-02
# 69       NEXN-AS1           3.346          8.156422e-02
# 70           MDC1           3.536          8.234836e-02
# 71           TCHH           3.626          8.234836e-02
# 72     SNORD116-8           2.359          8.234836e-02
# 73         CCDC17          -2.977          8.234836e-02
# 74            MOG          -4.551          8.234836e-02
# 75   LOC102724428           1.965          8.234836e-02
# 76            C4B          -3.889          8.234836e-02
# 77         KANSL1          -2.693          8.234836e-02
# 78           FLNC          -2.484          8.234836e-02
# 79          DPPA4           3.569          8.234836e-02
# 80          LLGL1          -2.127          8.234836e-02
# 81         ADARB2          -2.373          8.234836e-02
# 82          SP100           3.385          8.234836e-02
# 83         ZNF302           3.041          8.234836e-02
# 84           GMFB           3.253          8.234836e-02
# 85       SNORD118           2.999          8.477146e-02
# 86        TBC1D3I           6.391          8.533038e-02
# 87           PRG4           3.238          8.533038e-02
# 88       MGC16275          -2.254          8.533038e-02
# 89           AQP1          -1.718          8.533038e-02
# 90          TAGLN          -2.155          8.770908e-02
# 91        RNU5A-1           1.886          8.770908e-02
# 92           CD99          -1.823          8.770908e-02
# 93          RAB12           2.484          8.770908e-02
# 94        RNU5B-1           1.596          8.802626e-02
# 95         PARD6B           3.230          8.802626e-02
# 96         ARID3A           3.674          9.036603e-02
# 97            MAL          -2.385          9.049508e-02
# 98          BTBD9           3.130          9.049508e-02
# 99          RRP15           3.389          9.108483e-02
# 100       SNORD67           2.411          9.380661e-02
# 101           GPI          -2.702          9.482821e-02
# 102       RNU5E-1           2.675          9.747171e-02

# %% [markdown]
# # Up Regulated Genes

# %%
up = d[d['Log_FoldChange']>.5]
print(f"{up.shape}-->dataset's shape",f'||Amount of genes before removing duplication  {up.shape[0]}')
print('________________________________________________________________')
up = up.drop_duplicates(subset='Gene_symbol')
print(f"{up.shape}-->dataset's shape",f'||Amount of genes before removing duplication  {up.shape[0]}')

up[['Gene_symbol', 'Log_FoldChange','FDR_adjusted_P.value']]
# Out:
# (66, 8)-->dataset's shape ||Amount of genes before removing duplication  66
# ________________________________________________________________
# (59, 8)-->dataset's shape ||Amount of genes before removing duplication  59
#       Gene_symbol  Log_FoldChange  FDR_adjusted_P.value
# 0           HLA-E           9.675          6.221723e-15
# 3            ADI1           7.374          8.753403e-08
# 7            GNL1           3.803          1.294855e-05
# 12           PRR3           4.487          3.405242e-04
# 15          CXCL8           3.735          6.500416e-04
# 17          PCSK5           7.525          2.956713e-03
# 20   LOC100996721           6.039          8.448130e-03
# 21        NEUROD2           5.502          1.126761e-02
# 22          LMOD3           6.587          1.337313e-02
# 23          FGF23           5.450          1.519407e-02
# 26        SNORA21           5.360          2.709503e-02
# 27          RNU12           2.353          2.954453e-02
# 28      LOC554223           5.229          3.444740e-02
# 30          GREM1           4.585          3.444740e-02
# 32        CEBPZOS           4.611          3.808028e-02
# 34         CXCL14           3.924          4.142218e-02
# 35         LRRC69           4.403          4.255268e-02
# 36       RNU6ATAC           2.010          4.397319e-02
# 37           MUC4           4.416          4.824256e-02
# 38          NABP1           4.466          4.824256e-02
# 40    SNORD116-22           5.673          5.226233e-02
# 41          HLA-F           4.455          5.540448e-02
# 42         WT1-AS           5.579          5.540448e-02
# 43      LOC283038           4.227          5.540448e-02
# 44         COL6A3           4.080          5.540448e-02
# 45          PRRG3           3.882          5.540448e-02
# 46       MTRNR2L2           2.159          5.581676e-02
# 47          NCALD           4.094          6.723877e-02
# 49        FAM184B           3.999          7.001840e-02
# 51        SCARNA4           3.636          7.240748e-02
# 52          CXCL1           2.524          7.240748e-02
# 53      LINC00261           3.645          7.240748e-02
# 55           TPH1           4.447          7.240748e-02
# 56        SNORA81           1.813          7.240748e-02
# 59          MUC3A           5.048          7.281140e-02
# 60           DBET           5.332          7.281140e-02
# 61          S1PR2           4.281          7.281140e-02
# 63   LOC100506675           3.202          7.524935e-02
# 69       NEXN-AS1           3.346          8.156422e-02
# 70           MDC1           3.536          8.234836e-02
# 71           TCHH           3.626          8.234836e-02
# 72     SNORD116-8           2.359          8.234836e-02
# 75   LOC102724428           1.965          8.234836e-02
# 79          DPPA4           3.569          8.234836e-02
# 82          SP100           3.385          8.234836e-02
# 83         ZNF302           3.041          8.234836e-02
# 84           GMFB           3.253          8.234836e-02
# 85       SNORD118           2.999          8.477146e-02
# 86        TBC1D3I           6.391          8.533038e-02
# 87           PRG4           3.238          8.533038e-02
# 91        RNU5A-1           1.886          8.770908e-02
# 93          RAB12           2.484          8.770908e-02
# 94        RNU5B-1           1.596          8.802626e-02
# 95         PARD6B           3.230          8.802626e-02
# 96         ARID3A           3.674          9.036603e-02
# 98          BTBD9           3.130          9.049508e-02
# 99          RRP15           3.389          9.108483e-02
# 100       SNORD67           2.411          9.380661e-02
# 102       RNU5E-1           2.675          9.747171e-02

# %% [markdown]
# # Down Regulated Genes

# %%
down = d[d['Log_FoldChange']<-.5] #condition for finding downreagulated genes

print(f"dataset's shape{down.shape}",f'||Amount of genes before removing duplication  {down.shape[0]}')
print('________________________________________________________________')
down = down.drop_duplicates(subset='Gene_symbol') #removing duplicated genes
print(f"dataset's shape{down.shape}",f'||Amount of genes after removing duplication   {down.shape[0]}')

down[['Gene_symbol', 'Log_FoldChange','FDR_adjusted_P.value']]
# Out:
# dataset's shape(37, 8) ||Amount of genes before removing duplication  37
# ________________________________________________________________
# dataset's shape(33, 8) ||Amount of genes after removing duplication   33
#       Gene_symbol  Log_FoldChange  FDR_adjusted_P.value
# 4           PTGR1          -7.442          3.668371e-07
# 5             MOG          -8.569          5.160095e-06
# 10           GNL1          -5.388          1.294855e-05
# 11           PBX2          -4.052          1.284599e-04
# 14          HLA-C          -7.142          6.275805e-04
# 19          TPPP3          -2.440          7.813115e-03
# 24           PPT2          -5.273          2.270346e-02
# 25           DDR1          -5.241          2.270346e-02
# 29            NSF          -6.934          3.444740e-02
# 33         CHI3L2          -3.102          4.142218e-02
# 39          SMOC1          -2.307          5.157695e-02
# 48            DES          -6.082          6.903464e-02
# 50   LOC101929657          -3.303          7.240748e-02
# 54        SLC45A3          -2.605          7.240748e-02
# 57           KLK6          -2.597          7.240748e-02
# 62          HLA-B          -3.151          7.420031e-02
# 64          AP2A2          -1.742          7.597184e-02
# 65           PLTP          -1.762          7.597184e-02
# 66          CHADL          -2.281          7.978958e-02
# 67         ELOVL1          -2.415          7.981912e-02
# 68          AEBP1          -1.855          7.981912e-02
# 73         CCDC17          -2.977          8.234836e-02
# 76            C4B          -3.889          8.234836e-02
# 77         KANSL1          -2.693          8.234836e-02
# 78           FLNC          -2.484          8.234836e-02
# 80          LLGL1          -2.127          8.234836e-02
# 81         ADARB2          -2.373          8.234836e-02
# 88       MGC16275          -2.254          8.533038e-02
# 89           AQP1          -1.718          8.533038e-02
# 90          TAGLN          -2.155          8.770908e-02
# 92           CD99          -1.823          8.770908e-02
# 97            MAL          -2.385          9.049508e-02
# 101           GPI          -2.702          9.482821e-02
