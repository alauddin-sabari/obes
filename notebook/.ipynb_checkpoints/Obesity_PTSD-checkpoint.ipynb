# %% [markdown]
# # Obesity and Bipolar disorder [Down Regulated  Genes]

# %% [markdown]
# <img src= 'img/PTSD_up.png' style="float:left"> </img>

# %% [markdown]
# # Obesity andPosttraumatic stress disorder [Down Regulated  Genes]

# %% [markdown]
# <img src= 'img/PTSD_down.png' style="float:left"> </img>

# %%
import pandas as pd 
import numpy as np

#Import libraries
from matplotlib_venn import venn2, venn2_circles
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt

# %% [markdown]
# Dataset's link:<br>https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE58933

# %%
up = pd.read_csv('Obesity/appended_UP_Down_obes/up_appended_obes__.csv')
#up
down = pd.read_csv('Obesity/appended_UP_Down_obes/down_appended_obes__.csv')

# %%
up_down_obes = pd.concat([up,down])
up_down_obes.shape
# Out:
# (4146, 4)

# %%
up_down_obes = up_down_obes.drop_duplicates(subset='Gene_symbol')
up_down_obes.shape
# Out:
# (3880, 4)

# %%
up = up.drop_duplicates(subset='Gene_symbol')


set1up = set()

for i in up['Gene_symbol'].values:
 
    set1up.add(i)
 
 

 
down = down.drop_duplicates(subset='Gene_symbol')
 
set1down = set()
 
for i in down['Gene_symbol'].values:

    set1down.add(i)

# %% [markdown]
# # PTSD

# %%
up = pd.read_csv('PTSD/appended_UP_Down_/up_appended_PTSD.csv')
down = pd.read_csv('PTSD/appended_UP_Down_/down_appended_PTSD.csv')

# %%
up = up.drop_duplicates(subset='Gene_symbol')


set22up = set()

for i in up['Gene_symbol'].values:
 
    set22up.add(i)
 
 

down = down.drop_duplicates(subset='Gene_symbol')
 
set22down = set()
 
for i in down['Gene_symbol'].values:

    set22down.add(i)

# %%
from venn import venn
# %matplotlib inline

musicians = {
    "Obesity_up": set1up,
    "PTSD_up": set22up
    }
venn(musicians)
# Out:
# <AxesSubplot:>

# %%
from venn import venn
# %matplotlib inline

musicians = {
    "Obesity_down": set1down,
    "PTSD_down": set22down
    }
venn(musicians)
# Out:
# <AxesSubplot:>

# %% [markdown]
# # Schizophrenia

# %%
#d1['Log_FoldChange'] = d1.Log_FoldChange_x.astype(float) +d1.Log_FoldChange_y.astype(float) +d1.Log_FoldChange_x1.astype(float)+d1.Log_FoldChange_y1.astype(float)+d1.Log_FoldChange_x2.astype(float)+d1.Log_FoldChange_y2.astype(float)+d1.Log_FoldChange_x3.astype(float)+d1.Log_FoldChange_y3.astype(float)

# %%
up = pd.read_csv('Schizophrenia/appended_UP_Down_/up_appended_SZ.csv')
down = pd.read_csv('Schizophrenia/appended_UP_Down_/down_appended_SZ.csv')

# %%
up = up.drop_duplicates(subset='Gene_symbol')


set23up = set()

for i in up['Gene_symbol'].values:
 
    set23up.add(i)
 
 

 
down = down.drop_duplicates(subset='Gene_symbol')
 
set23down = set()
 
for i in down['Gene_symbol'].values:

    set23down.add(i)

# %%
from venn import venn
# %matplotlib inline

musicians = {
    "Obesity_up": set1up,
    "Schizophrenia_up": set23up
    }
venn(musicians)                   #15->11
# Out:
# <AxesSubplot:>

# %%
from venn import venn
# %matplotlib inline

musicians = {
    "Obesity_down": set1down,
    "Schizophrenia_down": set23down
    }
venn(musicians)      #30 - >18
# Out:
# <AxesSubplot:>

# %%
from venn import venn
# %matplotlib inline

musicians = {
    "Obesity": set1up,
    "Bipolar": set2up,
    "MDD": set21up,
    "PTSD": set22up,
    "SZ": set23up
    }
venn(musicians)
# Out:
# <AxesSubplot:>

# %%
list1 = list(set.intersection(set1up,set2up, set21up,set22up, set23up))
list1
# Out:
# ['MUC4', 'TRIM39']

# %%
list((set1up).intersection(set2up))   #x.apply(list)  x.apply(set)
# Out:
# ['ADCY4',
#  'CADPS2',
#  'C1orf54',
#  'DLG1-AS1',
#  'GLI3',
#  'MEI4',
#  'GNL1',
#  'TMC4',
#  'MUC4',
#  'TRABD2B',
#  'CRYAB',
#  'CR1',
#  'IFITM3',
#  'HGF',
#  'RN7SK',
#  'SDS',
#  'PAPSS2',
#  'TMEM176A',
#  'CD180',
#  'HCAR2',
#  'CD84',
#  'LCP1',
#  'LILRB4',
#  'ST14',
#  'TEX26-AS1',
#  'MIR1273G',
#  'SBSN',
#  'MUC16',
#  'LOC105375166',
#  'PRLR',
#  'PCSK5',
#  'KRT7',
#  'BHMT2',
#  'HNRNPA1P33',
#  'C9',
#  'HLA-DMA',
#  'APOC2',
#  'TEK',
#  'KIRREL3-AS2',
#  'LPAL2',
#  'GNGT2',
#  'MIR4313',
#  'MIR365B',
#  'SCARA5',
#  'COL6A3',
#  'CRYGN',
#  'CDKL1',
#  'CLUL1',
#  'LOC338963',
#  'HOXC6',
#  'NXF3',
#  'CD300A',
#  'GATA6',
#  'GKN2',
#  'LOC100505658',
#  'APBB1IP',
#  'ARHGEF35',
#  'SLCO2A1',
#  'IL1RN',
#  'B3GNT6',
#  'PLIN4',
#  'ABCA9-AS1',
#  'MMP8',
#  'TSPEAR-AS1',
#  'DDIT4L',
#  'JAK3',
#  'CD14',
#  'CAPN11',
#  'SIGLEC14',
#  'EVI2B',
#  'HLA-DQA1',
#  'GJA4',
#  'GABRE',
#  'WNT2',
#  'CYP1B1-AS1',
#  'COL11A2',
#  'OMD',
#  'HCG23',
# ...

# %%
fil= up.loc[up['Gene_symbol'].isin(x)]
fil
# Out:
#       Unnamed: 0      Gene_symbol  Log_FoldChange        PValue
# 13            23            ABCF1           3.152  9.454194e-09
# 17            31            CSMD1           4.386  2.044970e-08
# 23            39           FCGR2A           4.606  5.572134e-08
# 28            47            KCNA4           3.518  1.049181e-07
# 41            65         MTRNR2L8           4.977  6.095034e-07
# 82           134           SH3TC1           1.831  6.953132e-06
# 113          183            EGFL6           3.892  2.249915e-05
# 132          220             NPR1           3.414  4.499213e-05
# 167          288             CBSL           1.809  1.144858e-04
# 172          302            CRYAB           2.412  1.306903e-04
# 174          307            BICC1           1.243  1.437799e-04
# 192          357            FABP7           1.005  2.157645e-04
# 199          377            HLA-C           2.744  2.534925e-04
# 214          405           IFI44L           1.469  3.443753e-04
# ...

# %%
from venn import venn
# %matplotlib inline

musicians = {
    "Obesity": set1down,
    "Bipolar": set2down,
    "MDD": set21down,
    "PTSD": set22down,
    "SZ": set23down
    }
#venn(musicians)
venn(musicians)
# Out:
# <AxesSubplot:>

# %%
list2 =list(set.intersection(set1down,set2down, set21down,set22down, set23down))
set(list2).intersection(set(list1))
# Out:
# set()

# %%
flist = list1+list2
flist
# Out:
# ['MUC4',
#  'TRIM39',
#  'HSPA1B',
#  'HLA-DRB1',
#  'FOS',
#  'ATF3',
#  'NR4A3',
#  'RXRB',
#  'PPP1R18']

# %%
flist = list(dict.fromkeys(flist))
flist
# Out:
# ['MUC4',
#  'TRIM39',
#  'HSPA1B',
#  'HLA-DRB1',
#  'FOS',
#  'ATF3',
#  'NR4A3',
#  'RXRB',
#  'PPP1R18']

# %%
all_common_list = up_down_obes.loc[up_down_obes['Gene_symbol'].isin(flist)]
set(all_common_list['Gene_symbol'])
# Out:
# {'ATF3',
#  'FOS',
#  'HLA-DRB1',
#  'HSPA1B',
#  'MUC4',
#  'NR4A3',
#  'PPP1R18',
#  'RXRB',
#  'TRIM39'}

# %%
all_common_list.drop(columns='Unnamed: 0',inplace=True)
# Out:
# C:\Users\mjohi\.conda\envs\ml\lib\site-packages\pandas\core\frame.py:4901: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().drop(

# %%
all_common_list
all_common_list.drop_duplicates(subset='Gene_symbol',inplace=True)
all_common_list
# Out:
# C:\Users\mjohi\.conda\envs\ml\lib\site-packages\pandas\util\_decorators.py:311: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return func(*args, **kwargs)
#      Gene_symbol  Log_FoldChange    PValue
# 55        TRIM39        5.623000  0.000079
# 132      PPP1R18        1.450000  0.006991
# 288       HSPA1B        4.493000  0.000251
# 636     HLA-DRB1        1.796000  0.032137
# 2204        MUC4        1.049101  0.026595
# 275         ATF3       -2.089000  0.004857
# 300         RXRB       -2.320000  0.006891
# 480        NR4A3       -1.831000  0.026027
# 1593         FOS       -1.314225  0.028261

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_context("talk", font_scale=1.01)
plt.figure(figsize=(12,30))
sns.scatterplot(x="Log_FoldChange", 
                y="Gene_symbol",
                size="PValue",  #logfold/pvalue
                sizes=(200,1200),
                alpha=0.9,
                hue="PValue",
                data=fil[fil['Log_FoldChange']>1.5])
# Put the legend out of the figure
#plt.grid()
plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)

# %%
all_common_list
# Out:
#      Gene_symbol  Log_FoldChange    PValue
# 55        TRIM39        5.623000  0.000079
# 132      PPP1R18        1.450000  0.006991
# 288       HSPA1B        4.493000  0.000251
# 636     HLA-DRB1        1.796000  0.032137
# 2204        MUC4        1.049101  0.026595
# 275         ATF3       -2.089000  0.004857
# 300         RXRB       -2.320000  0.006891
# 480        NR4A3       -1.831000  0.026027
# 1593         FOS       -1.314225  0.028261

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns

sns.set_context("talk", font_scale=1.01)
plt.figure(figsize=(5,8))
sns.scatterplot(x="Log_FoldChange", 
                y="Gene_symbol",
                size="PValue",  #logfold/pvalue
                sizes=(500,2200),
                alpha=0.99,
                hue="PValue",
                data=all_common_list[abs(all_common_list['Log_FoldChange'])>1])
# Put the legend out of the figure
#plt.grid()
plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)

# %%
import stringdb
genes = list(all_common_list['Gene_symbol'])
string_ids = stringdb.get_string_ids(genes)
enrichment_df = stringdb.get_enrichment(string_ids.queryItem)
enrichment_df.to_csv('x.csv')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-44-eb9c37dbb037> in <module>
# ----> 1 import stringdb
#       2 genes = list(all_common_list['Gene_symbol'])
#       3 string_ids = stringdb.get_string_ids(genes)
#       4 enrichment_df = stringdb.get_enrichment(string_ids.queryItem)
#       5 enrichment_df.to_csv('x.csv')
#
# ModuleNotFoundError: No module named 'stringdb'

# %%
pd.read_csv('x.csv')

# %%
from venn import venn
# %matplotlib inline

musicians = {
    
    "Bipolar": set2up,
    "MDD": set21up,
    "PTSD": set22up,
    "SZ": set23up
    }
venn(musicians)

# %%
list1 = list(set.intersection(set2up, set21up,set22up, set23up))
list1

# %%
list2 =list(set.intersection(set2down, set21down,set22down, set23down))
#set(list2).intersection(set(list1))
list2

# %%
flist1 = list1+list2
flist1 = list(dict.fromkeys(flist1))
flist1

# %%
set(flist1).intersection(set(flist))

# %%
from venn import venn
# %matplotlib inline

musicians = {
    
    
    "MDD": set(flist1),
    "Bipolar": set(set.union(set1up,set1down))
    }
venn(musicians)

# %%
from venn import venn
# %matplotlib inline

musicians = {
    
    "Bipolar": set2down,
    "MDD": set21down,
    "PTSD": set22down,
    "SZ": set23down
    }
#venn(musicians)
venn(musicians)

# %%
set2up= set_up_SZ
set2down = set_down_SZ

# %%
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
penguins_data="https://raw.githubusercontent.com/datavizpyr/data/master/palmer_penguin_species.tsv"

# %%
sns.set_context("talk", font_scale=1.1)
plt.figure(figsize=(8,6))
sns.scatterplot(x="culmen_length_mm", 
                y="culmen_depth_mm", 
                data=penguins_df)
plt.xlabel("Culmen Length (mm)")
plt.ylabel("Culmen Depth (mm)")
plt.savefig("Seaborn_scatterplot.png",
                    format='png',dpi=150)

# %%
sns.set_context("talk", font_scale=1.1)
plt.figure(figsize=(10,6))
sns.scatterplot(x="culmen_length_mm", 
                y="culmen_depth_mm",
                size="body_mass_g",
                sizes=(20,500),
                alpha=0.5,
                hue="sex",
                data=penguins_df)
# Put the legend out of the figure
plt.legend(bbox_to_anchor=(1.01, 1),borderaxespad=0)
# Put the legend out of the figure
#plt.legend(bbox_to_anchor=(1.01, 0.54),  borderaxespad=0.)
plt.xlabel("Culmen Length (mm)")
plt.ylabel("Culmen Depth (mm)")
plt.title("Bubble plot with Colors in Seaborn")
plt.tight_layout()
 
plt.savefig("Bubble_plot_Seaborn_color_by_variable_Seaborn_scatterplot.png",
                    format='png',dpi=150)
