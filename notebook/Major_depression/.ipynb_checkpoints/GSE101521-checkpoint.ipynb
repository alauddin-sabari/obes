# %%
import pandas as pd 
import numpy as np

#Import libraries
from matplotlib_venn import venn2, venn2_circles
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %% [markdown]
# Dataset's link:<br>https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE58933

# %%
#nonsuicides
d  = pd.read_csv('GSE101521_major_depression_mdd_nonsuicides.csv')
d.head()
# Out:
#         Ensembl_ID Gene_symbol  Log_FoldChange  logCPM        PValue  \
# 0  ENSG00000109917        ZPR1           0.501   6.380  8.534608e-07
# 1  ENSG00000277808       LENG1           2.368  -1.668  6.028834e-06
# 2  ENSG00000100304      TTLL12           0.483   4.585  5.040662e-06
# 3  ENSG00000183018       SPNS2           0.436   5.046  6.722241e-06
# 4  ENSG00000133069       TMCC2           0.514   5.816  6.210875e-06
#
#    FDR_adjusted_P.value  Power   BCOV
# 0              0.021255  1.000  0.189
# 1              0.033482  0.945  0.932
# 2              0.033482  0.999  0.191
# 3              0.033482  1.000  0.175
# 4              0.033482  1.000  0.211

# %% [markdown]
# # Filtered Datataset

# %%
d  = d[(abs(d['Log_FoldChange'])>0.5) & (d['FDR_adjusted_P.value'] <0.1)]
d.dropna(subset = ['Gene_symbol'], inplace = True)
d[['Gene_symbol','Log_FoldChange','FDR_adjusted_P.value']]
# Out:
#      Gene_symbol  Log_FoldChange  FDR_adjusted_P.value
# 0           ZPR1           0.501              0.021255
# 1          LENG1           2.368              0.033482
# 4          TMCC2           0.514              0.033482
# 6          TCF19           3.582              0.055020
# 7           HCN2           0.656              0.056793
# 9           ADI1          -5.435              0.057466
# 10     LINC02003          -0.984              0.057466
# 11        UGT1A7          -0.767              0.057466
# 12        IGSF10          -0.627              0.057466
# 13          RHOF           0.619              0.057466
# 14        PCDH15          -0.662              0.057466
# 16          AATK           0.651              0.057466
# 20       KLHDC7A          -3.355              0.063503
# 21      MIR548X2          -1.097              0.063503
# 22       MIR3117          -1.143              0.063503
# 24           MBP           1.243              0.063503
# 26         FCHO1           0.502              0.068906
# 27       MIR3178           2.097              0.070788
# 28     LINC00517          -1.545              0.070788
# 29       C3orf52          -0.945              0.070788
# 31       EMILIN3           0.832              0.072415
# 32        PAIP2B           0.981              0.072820
# 33        RHBDL3           0.723              0.077704
# 34         LPAR1           0.979              0.078112
# 37         HSPA6          -5.676              0.081012
# 39         BCAS1           1.069              0.081012
# 42         MUC15          -0.741              0.083523
# 43        HAPLN2           0.820              0.084323
# 44         CENPB           0.529              0.084323
# 45  LOC100996671          -2.329              0.085918
# 46       SLFN12L          -0.572              0.085918
# 48     LINC01467          -1.068              0.089476
# 51      SLC9A3R2           0.653              0.089476
# 60          SUN2           0.529              0.089476
# 63         ABCA2           0.669              0.089476
# 64          IL1A          -2.230              0.089922
# 65       DMBT1P1          -1.128              0.089922
# 66       TEKT4P2           1.230              0.089922
# 67          FBN2          -0.716              0.089922
# 68         CXCL8          -3.759              0.089922
# 69          GYPE          -0.545              0.089922
# 71          GPC6          -0.549              0.089922
# 72          LIPE           0.691              0.089922
# 78         FCRL5          -0.543              0.089922
# 80       COL11A1          -0.514              0.089922
# 84        GABBR1          -3.062              0.089922
# 90       C6orf47          -6.613              0.091885
# 91       MIR7978          -1.164              0.095182
# 92          IL1B          -2.787              0.095182
# 93         AGBL1          -0.669              0.095182
# 94          GAB2           0.562              0.095182
# 96          SELE          -3.856              0.098985

# %% [markdown]
# # Up Regulated Genes

# %%
up = d[d['Log_FoldChange']>.5]
print(f"{up.shape}-->dataset's shape",f'||Amount of genes before removing duplication  {up.shape[0]}')
print('________________________________________________________________')
up = up.drop_duplicates(subset='Gene_symbol')
print(f"{up.shape}-->dataset's shape",f'||Amount of genes before removing duplication  {up.shape[0]}')

up[['Gene_symbol', 'Log_FoldChange','FDR_adjusted_P.value']]
# Out:
# (23, 8)-->dataset's shape ||Amount of genes before removing duplication  23
# ________________________________________________________________
# (23, 8)-->dataset's shape ||Amount of genes before removing duplication  23
#    Gene_symbol  Log_FoldChange  FDR_adjusted_P.value
# 0         ZPR1           0.501              0.021255
# 1        LENG1           2.368              0.033482
# 4        TMCC2           0.514              0.033482
# 6        TCF19           3.582              0.055020
# 7         HCN2           0.656              0.056793
# 13        RHOF           0.619              0.057466
# 16        AATK           0.651              0.057466
# 24         MBP           1.243              0.063503
# 26       FCHO1           0.502              0.068906
# 27     MIR3178           2.097              0.070788
# 31     EMILIN3           0.832              0.072415
# 32      PAIP2B           0.981              0.072820
# 33      RHBDL3           0.723              0.077704
# 34       LPAR1           0.979              0.078112
# 39       BCAS1           1.069              0.081012
# 43      HAPLN2           0.820              0.084323
# 44       CENPB           0.529              0.084323
# 51    SLC9A3R2           0.653              0.089476
# 60        SUN2           0.529              0.089476
# 63       ABCA2           0.669              0.089476
# 66     TEKT4P2           1.230              0.089922
# 72        LIPE           0.691              0.089922
# 94        GAB2           0.562              0.095182

# %% [markdown]
# # Down Regulated Genes

# %%
down = d[d['Log_FoldChange']<-.5] #condition for finding downreagulated genes

print(f"dataset's shape{down.shape}",f'||Amount of genes before removing duplication  {down.shape[0]}')
print('________________________________________________________________')
down = down.drop_duplicates(subset='Gene_symbol') #removing duplicated genes
print(f"dataset's shape{down.shape}",f'||Amount of genes after removing duplication   {down.shape[0]}')

down[['Gene_symbol', 'Log_FoldChange','FDR_adjusted_P.value']]
# Out:
# dataset's shape(29, 8) ||Amount of genes before removing duplication  29
# ________________________________________________________________
# dataset's shape(29, 8) ||Amount of genes after removing duplication   29
#      Gene_symbol  Log_FoldChange  FDR_adjusted_P.value
# 9           ADI1          -5.435              0.057466
# 10     LINC02003          -0.984              0.057466
# 11        UGT1A7          -0.767              0.057466
# 12        IGSF10          -0.627              0.057466
# 14        PCDH15          -0.662              0.057466
# 20       KLHDC7A          -3.355              0.063503
# 21      MIR548X2          -1.097              0.063503
# 22       MIR3117          -1.143              0.063503
# 28     LINC00517          -1.545              0.070788
# 29       C3orf52          -0.945              0.070788
# 37         HSPA6          -5.676              0.081012
# 42         MUC15          -0.741              0.083523
# 45  LOC100996671          -2.329              0.085918
# 46       SLFN12L          -0.572              0.085918
# 48     LINC01467          -1.068              0.089476
# 64          IL1A          -2.230              0.089922
# 65       DMBT1P1          -1.128              0.089922
# 67          FBN2          -0.716              0.089922
# 68         CXCL8          -3.759              0.089922
# 69          GYPE          -0.545              0.089922
# 71          GPC6          -0.549              0.089922
# 78         FCRL5          -0.543              0.089922
# 80       COL11A1          -0.514              0.089922
# 84        GABBR1          -3.062              0.089922
# 90       C6orf47          -6.613              0.091885
# 91       MIR7978          -1.164              0.095182
# 92          IL1B          -2.787              0.095182
# 93         AGBL1          -0.669              0.095182
# 96          SELE          -3.856              0.098985

# %%
#suicide
d  = pd.read_csv('GSE101521_major_depression_mdd_suicides.csv')
#d

# %% [markdown]
# # Filtered Datataset

# %%
d  = d[(abs(d['Log_FoldChange'])>0.5) & (d['FDR_adjusted_P.value'] <0.1)]
d.dropna(subset = ['Gene_symbol'], inplace = True)
d[['Gene_symbol','Log_FoldChange','FDR_adjusted_P.value']]
# Out:
#    Gene_symbol  Log_FoldChange  FDR_adjusted_P.value
# 0     MTRNR2L8           3.821          4.904401e-09
# 1        HSPA6          -6.008          6.937592e-06
# 2       HSPA1B          -4.992          4.495684e-04
# 3        CXCL8          -3.629          9.314727e-04
# 4          FOS          -1.964          9.314727e-04
# 5     SERPINH1          -2.589          1.695924e-03
# 6         ATF3          -1.990          3.221313e-03
# 7       FER1L6           2.045          3.753624e-03
# 8         CCL2          -2.491          5.498584e-03
# 9          MOG           1.947          1.009397e-02
# 10      CCL4L2          -3.075          1.329617e-02
# 11      CCL4L2          -3.076          1.329617e-02
# 12        CCL4          -4.492          1.329617e-02
# 13        FOSB          -1.715          1.653152e-02
# 14       CH25H          -1.309          1.918111e-02
# 15       PCSK5          -1.997          1.918111e-02
# 16      DNAJB1          -1.427          1.918111e-02
# 17       NPAS4          -2.197          2.529651e-02
# 18       NR4A1          -1.202          2.683737e-02
# 19        MDC1           2.466          3.117957e-02
# 20      HSPA1B          -1.876          3.413678e-02
# 21        SELE          -2.892          3.441996e-02
# 22        VARS          -1.342          3.729805e-02
# 23        VARS          -1.342          3.729805e-02
# 24        VARS          -1.338          3.975566e-02
# 25     TNFAIP3          -1.594          4.463964e-02
# 26        CCL4          -2.281          5.153834e-02
# 27        IL1B          -2.041          7.031039e-02
# 28      CDKN1A          -1.498          8.379815e-02
# 29       RGS16          -1.133          9.312706e-02

# %% [markdown]
# # Up Regulated Genes

# %%
up = d[d['Log_FoldChange']>.5]
print(f"{up.shape}-->dataset's shape",f'||Amount of genes before removing duplication  {up.shape[0]}')
print('________________________________________________________________')
up = up.drop_duplicates(subset='Gene_symbol')
print(f"{up.shape}-->dataset's shape",f'||Amount of genes before removing duplication  {up.shape[0]}')

up[['Gene_symbol', 'Log_FoldChange','FDR_adjusted_P.value']]
# Out:
# (4, 8)-->dataset's shape ||Amount of genes before removing duplication  4
# ________________________________________________________________
# (4, 8)-->dataset's shape ||Amount of genes before removing duplication  4
#    Gene_symbol  Log_FoldChange  FDR_adjusted_P.value
# 0     MTRNR2L8           3.821          4.904401e-09
# 7       FER1L6           2.045          3.753624e-03
# 9          MOG           1.947          1.009397e-02
# 19        MDC1           2.466          3.117957e-02

# %% [markdown]
# # Down Regulated Genes

# %%
down = d[d['Log_FoldChange']<-.5] #condition for finding downreagulated genes

print(f"dataset's shape{down.shape}",f'||Amount of genes before removing duplication  {down.shape[0]}')
print('________________________________________________________________')
down = down.drop_duplicates(subset='Gene_symbol') #removing duplicated genes
print(f"dataset's shape{down.shape}",f'||Amount of genes after removing duplication   {down.shape[0]}')

down[['Gene_symbol', 'Log_FoldChange','FDR_adjusted_P.value']]
# Out:
# dataset's shape(26, 8) ||Amount of genes before removing duplication  26
# ________________________________________________________________
# dataset's shape(21, 8) ||Amount of genes after removing duplication   21
#    Gene_symbol  Log_FoldChange  FDR_adjusted_P.value
# 1        HSPA6          -6.008              0.000007
# 2       HSPA1B          -4.992              0.000450
# 3        CXCL8          -3.629              0.000931
# 4          FOS          -1.964              0.000931
# 5     SERPINH1          -2.589              0.001696
# 6         ATF3          -1.990              0.003221
# 8         CCL2          -2.491              0.005499
# 10      CCL4L2          -3.075              0.013296
# 12        CCL4          -4.492              0.013296
# 13        FOSB          -1.715              0.016532
# 14       CH25H          -1.309              0.019181
# 15       PCSK5          -1.997              0.019181
# 16      DNAJB1          -1.427              0.019181
# 17       NPAS4          -2.197              0.025297
# 18       NR4A1          -1.202              0.026837
# 21        SELE          -2.892              0.034420
# 22        VARS          -1.342              0.037298
# 25     TNFAIP3          -1.594              0.044640
# 27        IL1B          -2.041              0.070310
# 28      CDKN1A          -1.498              0.083798
# 29       RGS16          -1.133              0.093127
