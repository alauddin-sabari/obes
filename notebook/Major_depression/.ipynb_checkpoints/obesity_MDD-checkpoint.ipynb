# %% [markdown]
#  obesity dataset:

# %%
import pandas as pd 
import numpy as np

#Import libraries
from matplotlib_venn import venn2, venn2_circles
from matplotlib_venn import venn3, venn3_circles
from matplotlib import pyplot as plt

pd.set_option('display.max_rows', None)
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)

# %%
#file upload

d  = pd.read_csv('../GSE81965_obes_ngt.csv')
d  = d[(abs(d['Log_FoldChange'])>1) & (d['FDR_adjusted_P.value'] <0.05)]

# %%
d
# Out:
#            Ensembl_ID     Gene_symbol  Log_FoldChange  logCPM        PValue  \
# 0     ENSG00000134207            SYT6          -2.682   2.100  4.706418e-26
# 1     ENSG00000204536          CCHCR1           2.976   1.900  1.027263e-20
# 2     ENSG00000137310           TCF19           7.046   1.079  1.281481e-19
# 3     ENSG00000106819            ASPN           4.951   5.750  8.046694e-19
# 4     ENSG00000277104          TADA2A           3.269   1.836  3.206177e-17
# 5     ENSG00000239927           RPP21           5.147   0.918  4.147770e-17
# 6     ENSG00000106809             OGN           6.961   4.503  6.671445e-17
# 7     ENSG00000262243            CES1           6.373   2.793  2.582880e-16
# 8     ENSG00000154265           ABCA5           1.793   2.585  1.891319e-15
# 9     ENSG00000099994           SUSD2           3.486   4.770  2.097683e-15
# 10    ENSG00000184347           SLIT3           5.703   8.101  3.765150e-15
# ...

# %% [markdown]
# Dataset1<br>https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE81965

# %%
up = d[d['Log_FoldChange']>1]
up = up.drop_duplicates(subset='Gene_symbol')

set1up = set()
for i in up['Gene_symbol'].values:
    set1up.add(i)
    
#down
down = d[d['Log_FoldChange']<-1]
down = down.drop_duplicates(subset='Gene_symbol')
set1down = set()
for i in down['Gene_symbol'].values:
    set1down.add(i)

# %%
up['Gene_symbol']
# Out:
# 1             CCHCR1
# 2              TCF19
# 3               ASPN
# 4             TADA2A
# 5              RPP21
# 6                OGN
# 7               CES1
# 8              ABCA5
# 9              SUSD2
# 10             SLIT3
# 11             SVEP1
# 12             DHX16
# 13           COL21A1
# 14             WDR63
# 15            CACNB4
# 16             PDGFD
# 17             ABCA8
# 18             PDE5A
# 19            CHRDL1
# 20               NDN
# 21             MFAP4
# 22             PRRX1
# 23             HSPB6
# 24            EMX2OS
# 25               ACE
# 28             ADH1B
# 29              STAC
# 30             PTGES
# 31             PTGIS
# 32             LRRN3
# 33          SERPINI1
# 34            SLC1A1
# 35         LINC00960
# 36              NPR1
# 38            NYNRIN
# 40           XPNPEP2
# 41             TSHZ2
# 42          ARHGAP20
# 43             SFRP1
# 44             FBLN5
# 46            NCKAP5
# 47             MASP1
# 50              TNXB
# ...

# %%
down['Gene_symbol']
# Out:
# 0                 SYT6
# 26              TAS1R1
# 27               DMBT1
# 37              SEMA6B
# 45               CADM1
# 48             SLC12A7
# 49               AIF1L
# 54             PCDHB11
# 60                MLPH
# 65                HES2
# 67              FAM95C
# 78               HLA-B
# 99                MMP1
# 106              PTGDS
# 108                DXO
# 118            TMEM108
# 129              AS3MT
# 135             KHDC1L
# 138              CORO7
# 157              LCNL1
# 167           ANKRD18A
# 168              HLA-F
# 170                SHD
# 174              KISS1
# 179              DOC2B
# 189              N4BP3
# 193              PADI2
# 209             UGT2B4
# 215              OXCT2
# 217             DDX39B
# 221               ASB2
# 239               MDC1
# 273               ERFE
# 278              P2RX6
# 288               AFF2
# 296               PWP2
# 304           C21orf33
# 313           DEFB103B
# 314           DEFB103A
# 322             PIEZO2
# ...

# %%
d1 = pd.read_csv('GSE119290_SZ_hiPSC NPCs_DMSO.csv')
d1 = d1[(abs(d1['Log_FoldChange'])>1) & (d1['FDR_adjusted_P.value'] <0.05)]

# %%
d1
# Out:
#           Ensembl_ID   Gene_symbol  Log_FoldChange  logCPM        PValue  \
# 0    ENSG00000235712          RXRB          -7.005   3.266  4.589516e-19
# 1    ENSG00000145736        GTF2H2          -1.905   3.073  2.789272e-13
# 2    ENSG00000164930          FZD6          -2.100   4.999  6.172237e-13
# 3    ENSG00000132164       SLC6A11           7.387   5.217  7.318182e-13
# 4    ENSG00000282019           GPI          -5.242   2.851  1.122421e-12
# 5    ENSG00000274229         SOCS7          -3.729   3.223  2.054470e-12
# 6    ENSG00000206315          PBX2          -5.738   4.136  2.310349e-12
# 7    ENSG00000157150         TIMP4           3.166   3.689  2.291189e-11
# 8    ENSG00000176533          GNG7           3.722   5.483  3.540273e-11
# 9    ENSG00000132975         GPR12           7.100   2.073  1.931248e-10
# 10   ENSG00000132692          BCAN           5.766   6.593  1.826163e-10
# 11   ENSG00000007171          NOS2          -4.868   1.100  8.764238e-10
# ...

# %%
d1.shape
# Out:
# (559, 8)

# %% [markdown]
# Dataset2<br>https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE66216

# %%
up = d1[d1['Log_FoldChange']>1]
up = up.drop_duplicates(subset='Gene_symbol')

set2up = set()
for i in up['Gene_symbol'].values:
    set2up.add(i)
    
#down
down = d1[d1['Log_FoldChange']<-1]
down = down.drop_duplicates(subset='Gene_symbol')
set2down = set()
for i in down['Gene_symbol'].values:
    set2down.add(i)

# %%
# %matplotlib inline
#venn2(subsets = (30, 10, 5), set_labels = ('Group A', 'Group B'))
venn2([set1up,set2up])
plt.title('obesity vs colorectal cancer (upregulated gene)')
# Out:
# Text(0.5, 1.0, 'obesity vs colorectal cancer (upregulated gene)')

# %%
# %matplotlib inline
v=venn2(subsets=(set1down,set2down),set_labels=('obesity up','colorectal up'), set_colors=('purple', 'skyblue'), alpha = 0.7)
#venn2_circles()
plt.title('obesity vs colorectal cancer (downregulated gene)')
# Out:
# Text(0.5, 1.0, 'obesity vs colorectal cancer (downregulated gene)')

# %%
d3 = pd.read_csv('GSE121376_cortical_interneurons_tissue.csv')
d3 = d3[(abs(d3['Log_FoldChange'])>1) & (d3['FDR_adjusted_P.value'] <0.05)]

# %% [markdown]
# Dataset3:<br>https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE114069

# %%
up = d3[d3['Log_FoldChange']>1]
up = up.drop_duplicates(subset='Gene_symbol')

set3up = set()
for i in up['Gene_symbol'].values:
    set3up.add(i)
    
#down
down = d3[d3['Log_FoldChange']<-1]
down = down.drop_duplicates(subset='Gene_symbol')
set3down = set()
for i in down['Gene_symbol'].values:
    set3down.add(i)

# %%
venn2([set3up,set1up])
plt.title('obesity vs Thyroid cancer (upregulated gene)')
# Out:
# Text(0.5, 1.0, 'obesity vs Thyroid cancer (upregulated gene)')

# %%
venn2([set3down,set1down])
plt.title('obesity vs Thyroid cancer f(downregulated gene)')
# Out:
# Text(0.5, 1.0, 'obesity vs Thyroid cancer f(downregulated gene)')

# %%
d4 = pd.read_csv('GSE78936/GSE78936_Schizophrenia_BA11.csv')
d4 = d4[(abs(d4['Log_FoldChange'])>1) & (d4['FDR_adjusted_P.value'] <0.05)]

# %% [markdown]
# Dataset4  GSE144274 idiopathic pulmonary hypertension:<br>https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE144274

# %%
up = d4[d4['Log_FoldChange']>1]
up = up.drop_duplicates(subset='Gene_symbol')

set4up = set()
for i in up['Gene_symbol'].values:
    set4up.add(i)
    
#down
down = d4[d4['Log_FoldChange']<-1]
down = down.drop_duplicates(subset='Gene_symbol')
set4down = set()
for i in down['Gene_symbol'].values:
    set4down.add(i)

# %%
venn2([set1up,set4up])
plt.title('obesity vs Hypertension (upregulated)')
# Out:
# Text(0.5, 1.0, 'obesity vs Hypertension (upregulated)')

# %%
venn2([set1down,set4down])
plt.title('obesity vs Hypertension (downregulated)')
# Out:
# Text(0.5, 1.0, 'obesity vs Hypertension (downregulated)')

# %%
d41 = pd.read_csv('GSE78936/GSE78936_SZ_BA24(Brain_area_24)_.csv')
d41 = d41[(abs(d41['Log_FoldChange'])>1) & (d41['PValue'] <0.05)]

# %% [markdown]
# Dataset4  GSE144274 idiopathic pulmonary hypertension:<br>https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE144274

# %%
up = d41[d41['Log_FoldChange']>1]
up = up.drop_duplicates(subset='Gene_symbol')

set41up = set()
for i in up['Gene_symbol'].values:
    set41up.add(i)
    
#down
down = d41[d41['Log_FoldChange']<-1]
down = down.drop_duplicates(subset='Gene_symbol')
set41down = set()
for i in down['Gene_symbol'].values:
    set41down.add(i)

# %%
venn2([set1up,set41up])
plt.title('obesity vs Hypertension (upregulated)')
# Out:
# Text(0.5, 1.0, 'obesity vs Hypertension (upregulated)')

# %%
venn2([set1down,set41down])
plt.title('obesity vs Hypertension (downregulated)')
# Out:
# Text(0.5, 1.0, 'obesity vs Hypertension (downregulated)')

# %%
d5 = pd.read_csv('GSE78936/GSE78936_SZ_BA9.csv')
d5 = d5[(abs(d5['Log_FoldChange'])>1) & (d5['PValue'] <0.05)]

# %% [markdown]
# Dataset4  GSE144274 idiopathic pulmonary hypertension:<br>https://www.ncbi.nlm.nih.gov/geo/query/acc.cgi?acc=GSE144274

# %%
up = d5[d5['Log_FoldChange']>1]
up = up.drop_duplicates(subset='Gene_symbol')

set5up = set()
for i in up['Gene_symbol'].values:
    set5up.add(i)
    
#down
down = d5[d5['Log_FoldChange']<-1]
down = down.drop_duplicates(subset='Gene_symbol')
set5down = set()
for i in down['Gene_symbol'].values:
    set5down.add(i)

# %%
venn2([set1up,set5up])
plt.title('obesity vs Hypertension (upregulated)')
# Out:
# Text(0.5, 1.0, 'obesity vs Hypertension (upregulated)')

# %%
venn2([set1down,set41down])
plt.title('obesity vs Hypertension (downregulated)')
# Out:
# Text(0.5, 1.0, 'obesity vs Hypertension (downregulated)')

# %%
import matplotlib_venn as vplt
import matplotlib.pyplot as plt

plt.figure(figsize=(10,10))
plt.subplot(1, 2, 1)
plt.title('Subplot 1')
v = vplt.venn2(subsets=(10,10,1), set_labels=('A', 'B'), set_colors=('w', 'w'))
c = vplt.venn2_circles(subsets=(2, 2, 1), linestyle='solid')
c[0].set_radius(0.32)
c[1].set_radius(0.32)
c[0].set_lw(2.0)
c[1].set_lw(2.0)
c[0].set_color('green')
c[1].set_color('red')
c[0].set_alpha(0.5)
c[1].set_alpha(0.5)
c[0].set_edgecolor('black')
c[1].set_edgecolor('black')

plt.subplot(1, 2, 2)
plt.title('Subplot 2')
v = vplt.venn2(subsets=(10,1000,1), set_labels=('A', 'B'), set_colors=('w', 'w'))
v.get_label_by_id('10').set_x(0.25)
v.get_label_by_id('01').set_x(-.25)
v.get_label_by_id('11').set_x(0)
v.set_labels[0].set_position((-0.22, -0.45))
v.set_labels[1].set_position((0.25, -0.45))


c = vplt.venn2_circles(subsets=(2, 2, 1), linestyle='solid')
c[0].set_radius(0.32)
c[1].set_radius(0.32)
c[0].set_lw(2.0)
c[1].set_lw(2.0)
c[0].set_color('green')
c[1].set_color('red')
c[0].set_alpha(0.5)
c[1].set_alpha(0.5)
c[0].set_edgecolor('black')
c[1].set_edgecolor('black')
